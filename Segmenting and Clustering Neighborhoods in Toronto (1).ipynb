# %%
import requests 
import pandas as pd 
import numpy as np 
import random
import geocoder
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-c0dfa92b61d1> in <module>
#       3 import numpy as np
#       4 import random
# ----> 5 import geocoder
#       6 import folium
#       7 import matplotlib.cm as cm
#
# ModuleNotFoundError: No module named 'geocoder'

# %%
page='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page_wikipedia=requests.get(page)
page_raw = pd.read_html(page_wikipedia.content, header = 0)[0]
df = page_raw[page_raw.Neighborhood != 'Not assigned']
df.reset_index(inplace = True)
df.head()
# Out:
#    index Postal Code           Borough  \
# 0      2         M3A        North York
# 1      3         M4A        North York
# 2      4         M5A  Downtown Toronto
# 3      5         M6A        North York
# 4      6         M7A  Downtown Toronto
#
#                                   Neighborhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
df = df.reset_index()
df.drop(['index'], axis = 'columns', inplace = True)
df = df.set_index('level_0')

# %%
df.head()
# Out:
#    level_0  index Postal Code           Borough  \
# 0        0      2         M3A        North York
# 1        1      3         M4A        North York
# 2        2      4         M5A  Downtown Toronto
# 3        3      5         M6A        North York
# 4        4      6         M7A  Downtown Toronto
#
#                                   Neighborhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
from geopy.geocoders import Nominatim 

add = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(add)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

toronto_merged_nonan = toronto_merged.dropna(subset=['Cluster Labels'])
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged_nonan['Latitude'], toronto_merged_nonan['Longitude'], toronto_merged_nonan['Neighborhood'], toronto_merged_nonan['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-76c906ae9fc4> in <module>
#       1
# ----> 2 map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
#       3 x = np.arange(kclusters)
#       4 ys = [i + x + (i*x)**2 for i in range(kclusters)]
#       5 colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
#
# NameError: name 'folium' is not defined
